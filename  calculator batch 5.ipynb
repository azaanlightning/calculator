# %%
import tkinter as tk
from tkinter import*

# %%
root = tk.Tk()
root.geometry("400x400")
root.configure(bg="yellow") 

mylable = tk.Label(root, text="Calculator", bg="pink")
mylable.grid(row=0, column= 1)
operator=""
text_input = StingVar
def btnClick(number):
    global operator
    operator=operator+str(number)
    text_input.set(operator)

txtDisplay= Entry(root, font="arial", 20, "bold" )
def click_me1():
    B1.configure(text="7")
    mylable.configure(text="7")
    
def click_me2():
    B2.configure(text="4")
    mylable.configure(text="4")
    
def click_me3():
    B3.configure(text="1")
    mylable.configure(text="1")

def click_me4():
    B4.configure(text="0")
    mylable.configure(text="0")

    

def click_me5():
    B1.configure(text="8")
    mylable.configure(text="8")
    
def click_me6():
    B2.configure(text="5")
    mylable.configure(text="5")
    
def click_me7():
    B3.configure(text="7")
    mylable.configure(text="7")

def click_me8():
    B4.configure(text="C")
    mylable.configure(text="C")    
    

def click_me9():
    B1.configure(text="9")
    mylable.configure(text="9")
    
def click_me10():
    B2.configure(text="6")
    mylable.configure(text="6")
    
def click_me11():
    B3.configure(text="3")
    mylable.configure(text="3")

def click_me12():
    B4.configure(text="=")
    mylable.configure(text="=")


def click_me13():
    B1.configure(text="+")
    mylable.configure(text="+")
    
def click_me14():
    B2.configure(text="-")
    mylable.configure(text="-")
    
def click_me15():
    B3.configure(text="*")
    mylable.configure(text="*")

def click_me16():
    B4.configure(text="/")
    mylable.configure(text="/")
    
B1 = Button(root,padx=16, bd=8,(font='arial',20,"bold"), text="7", bg="yellow", command = lambda:btnClick(0))
B1.grid(row=1, column=1)

B2 = Button(root,padx=16, bd=8,(font='arial',20,"bold"), text="4", bg="yellow",command= lambda:btnClick((4))
B2.grid(row=2, column=1)

B3 = Button(root, text="1", bg="yellow", command=click_me3)
B3.grid(row=3, column=1
B4 = Button(root, text="0", bg="yellow", command=click_me4)
B4.grid(row=4, column=1)

B5 = Button(root, text="8", bg="yellow", command=click_me5)
B5.grid(row=1, column=2)

B6 = Button(root, text="5", bg="yellow", command=click_me6)
B6.grid(row=2, column=2)

B7 = Button(root, text="2", bg="yellow", command=click_me7)
B7.grid(row=3, column=2)

B8 = Button(root, text="C", bg="yellow", command=click_me8)
B8.grid(row=4, column=2)

B9 = Button(root, text="9", bg="yellow", command=click_me9)
B9.grid(row=1, column=3)

B10 = Button(root, text="6", bg="yellow", command=click_me10)
B10.grid(row=2, column=3)

B11= Button(root, text="3", bg="yellow", command=click_me11)
B11.grid(row=3, column=3)

B12= Button(root, text="=", bg="yellow", command=click_me12)
B12.grid(row=4, column=3)

B13 = Button(root, text="+", bg="yellow", command=click_me13)
B13.grid(row=1, column=4)

B14 = Button(root, text="-", bg="yellow", command=click_me14)
B14.grid(row=2, column=4)

B15 = Button(root, text="*", bg="yellow", command=click_me15)
B15.grid(row=3, column=4)

B16= Button(root, text="/", bg="yellow", command=click_me16)
B16.grid(row=4, column=4)
root.mainloop()

# %%
root = tk.Tk()
root.geometry("400x400")
root.configure(bg="yellow") 


operator=""
text_input = StingVar
def btnClick(number):
    global operator
    operator=operator+str(number)
    text_input.set(operator)
    
def btnEquals():
    global operator
    ans = str(eval(number))
    text_input.set(ans)

def btnClear():
    global operator
    operator=""
    text_input.set("")

txtDisplay= Entry(cal, font=('arial',20,'bold',), textvariable=text_input, bd =30, insertwidth=4,
                  bg="black", justify="right")
txtDisplay.grid(columnspan=4)
    
B1 = Button(root,padx=16, bd=8,(font='arial',20,"bold"), text="7", bg="yellow", command = lambda:btnClick(0))
B1.grid(row=1, column=1)

B2 = Button(root,padx=16, bd=8,(font='arial',20,"bold"), text="4", bg="yellow",command= lambda:btnClick((4))
B2.grid(row=2, column=1)

B3 = Button(root,padx=16, bd=8,(font='arial',20,"bold"), text="1", bg="yellow", command=lambda:btnClick(1))
B3.grid(row=3, column=1
B4 = Button(root, padx=16, bd=8,(font='arial',20,"bold"), text="0", bg="yellow", command=lambda:btnClick(0))
B4.grid(row=4, column=1)

B5 = Button(root, padx=16, bd=8,(font='arial',20,"bold"),text="8", bg="yellow", command=click_me5)
B5.grid(row=1, column=2)

B6 = Button(root, padx=16, bd=8,(font='arial',20,"bold"),text="5", bg="yellow", command=click_me6)
B6.grid(row=2, column=2)

B7 = Button(root,padx=16, bd=8,(font='arial',20,"bold"), text="2", bg="yellow", command=click_me7)
B7.grid(row=3, column=2)

B8 = Button(root, padx=16, bd=8,(font='arial',20,"bold"),text="C", bg="yellow", command=click_me8)
B8.grid(row=4, column=2)

B9 = Button(root,padx=16, bd=8,(font='arial',20,"bold"), text="9", bg="yellow", command=click_me9)
B9.grid(row=1, column=3)

B10 = Button(root, padx=16, bd=8,(font='arial',20,"bold"),text="6", bg="yellow", command=click_me10)
B10.grid(row=2, column=3)

B11= Button(root, padx=16, bd=8,(font='arial',20,"bold"),text="3", bg="yellow", command=click_me11)
B11.grid(row=3, column=3)

B12= Button(root, padx=16, bd=8,(font='arial',20,"bold"),text="=", bg="yellow", command=click_me12)
B12.grid(row=4, column=3)

B13 = Button(root,padx=16, bd=8,(font='arial',20,"bold"), text="+", bg="yellow", command=click_me13)
B13.grid(row=1, column=4)

B14 = Button(root,padx=16, bd=8,(font='arial',20,"bold"), text="-", bg="yellow", command=click_me14)
B14.grid(row=2, column=4)

B15 = Button(root, padx=16, bd=8,(font='arial',20,"bold"),text="*", bg="yellow", command=click_me15)
B15.grid(row=3, column=4)

B16= Button(root, padx=16, bd=8,(font='arial',20,"bold"),text="/", bg="yellow", command=click_me16)
B16.grid(row=4, column=4)
root.mainloop()
